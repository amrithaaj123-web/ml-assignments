# %%
a = "earth"
b = "heart"
if sorted(a) == sorted(b):
    print("Anagrams")
else:
    print("Not Anagrams")
# Out:
# Anagrams

# %%
def k_closest(points, k):
    points.sort(key=lambda p: p[0]**2 + p[1]**2)
    return points[:k]
points = [(7,1), (2,2), (-1,4), (0,-2)]
k = 2
print(k_closest(points, k))
# Out:
# [(0, -2), (2, 2)]
